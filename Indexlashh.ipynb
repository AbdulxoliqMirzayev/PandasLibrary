# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulxoliqMirzayev/PandasLibrary/blob/main/Indexlashh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Yil':[2021,2020,2019,2018,2017,2016,2015,2010],
    'Aholi soni':[33.9,33.5,32.9,32.5,31.9,31.4,30.9,28.5],
    'Temp':[1.54,1.48,1.56,1.62,1.65,1.66,1.64,1.53]
}
df=pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
df.head()
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65

# %%
df.shape
# Out:
# (8, 3)

# %%
#### Data frame ustunlari

# %%
df = pd.DataFrame(data, columns = ['Yil','Temp','Aholi soni'])

# %%
df
# Out:
#     Yil  Temp  Aholi soni
# 0  2021  1.54        33.9
# 1  2020  1.48        33.5
# 2  2019  1.56        32.9
# 3  2018  1.62        32.5
# 4  2017  1.65        31.9
# 5  2016  1.66        31.4
# 6  2015  1.64        30.9
# 7  2010  1.53        28.5

# %%
df = pd.DataFrame(data, columns = ['Yil','Temp','Aholi soni', 'YAIM'])

# %%
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# 0  2021  1.54        33.9  NaN
# 1  2020  1.48        33.5  NaN
# 2  2019  1.56        32.9  NaN
# 3  2018  1.62        32.5  NaN
# 4  2017  1.65        31.9  NaN
# 5  2016  1.66        31.4  NaN
# 6  2015  1.64        30.9  NaN
# 7  2010  1.53        28.5  NaN

# %%
df['Aholi soni']
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# 4    31.9
# 5    31.4
# 6    30.9
# 7    28.5
# Name: Aholi soni, dtype: float64

# %%
df.Temp
# Out:
# 0    1.54
# 1    1.48
# 2    1.56
# 3    1.62
# 4    1.65
# 5    1.66
# 6    1.64
# 7    1.53
# Name: Temp, dtype: float64

# %%
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# 0  2021  1.54        33.9  NaN
# 1  2020  1.48        33.5  NaN
# 2  2019  1.56        32.9  NaN
# 3  2018  1.62        32.5  NaN
# 4  2017  1.65        31.9  NaN
# 5  2016  1.66        31.4  NaN
# 6  2015  1.64        30.9  NaN
# 7  2010  1.53        28.5  NaN

# %%
df.YAIM=0
df
# Out:
#     Yil  Temp  Aholi soni  YAIM
# 0  2021  1.54        33.9     0
# 1  2020  1.48        33.5     0
# 2  2019  1.56        32.9     0
# 3  2018  1.62        32.5     0
# 4  2017  1.65        31.9     0
# 5  2016  1.66        31.4     0
# 6  2015  1.64        30.9     0
# 7  2010  1.53        28.5     0

# %%
val = pd.Series([1700,1650,1750,1350,1480,1700,1800])
df.YAIM=val
df
# Out:
#     Yil  Temp  Aholi soni    YAIM
# 0  2021  1.54        33.9  1700.0
# 1  2020  1.48        33.5  1650.0
# 2  2019  1.56        32.9  1750.0
# 3  2018  1.62        32.5  1350.0
# 4  2017  1.65        31.9  1480.0
# 5  2016  1.66        31.4  1700.0
# 6  2015  1.64        30.9  1800.0
# 7  2010  1.53        28.5     NaN

# %%
df['1500+']= df.YAIM>1500
df
# Out:
#     Yil  Temp  Aholi soni    YAIM  1500+
# 0  2021  1.54        33.9  1700.0   True
# 1  2020  1.48        33.5  1650.0   True
# 2  2019  1.56        32.9  1750.0   True
# 3  2018  1.62        32.5  1350.0  False
# 4  2017  1.65        31.9  1480.0  False
# 5  2016  1.66        31.4  1700.0   True
# 6  2015  1.64        30.9  1800.0   True
# 7  2010  1.53        28.5     NaN  False

# %%
del df['1500+']
df
# Out:
#     Yil  Temp  Aholi soni    YAIM
# 0  2021  1.54        33.9  1700.0
# 1  2020  1.48        33.5  1650.0
# 2  2019  1.56        32.9  1750.0
# 3  2018  1.62        32.5  1350.0
# 4  2017  1.65        31.9  1480.0
# 5  2016  1.66        31.4  1700.0
# 6  2015  1.64        30.9  1800.0
# 7  2010  1.53        28.5     NaN

# %%
#### Lug'atdan dta frame******************************

# %%
data1 = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}

# %%
df2 = pd.DataFrame(data1)
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2.index.name='Yil'
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2=pd.DataFrame(data1,index=[2021,2019,2017])
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
df2.T
# Out:
#             2021  2019  2017
# Uzbekistan  33.9  32.9  31.9
# Kazakhstan  18.9  18.5  18.1

# %%
arr =df2.values
arr
# Out:
# array([[33.9, 18.9],
#        [32.9, 18.5],
#        [31.9, 18.1]])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
df2.index
# Out:
# Int64Index([2021, 2019, 2017], dtype='int64')

# %%
indeks = df2.columns

# %%
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# 0  2021  1.54        33.9  NaN
# 1  2020  1.48        33.5  NaN
# 2  2019  1.56        32.9  NaN
# 3  2018  1.62        32.5  NaN
# 4  2017  1.65        31.9  NaN
# 5  2016  1.66        31.4  NaN
# 6  2015  1.64        30.9  NaN
# 7  2010  1.53        28.5  NaN

# %%
usernames = {"anvar":"anvarbek23","olim":"olimtoy","maryam":"mary334455","javohir":"javohir45"}
emails= {"anvar":"anvar@gmail.com","olim":"olimtoy@gmail.ru","maryam":"mary33@gmail.com","javohir":"javohir445@gmail.com"}
dataa = {
    'username': usernames,
    'email':emails
}
df = pd.DataFrame(dataa)

# %%
df
# Out:
#            username                 email
# anvar    anvarbek23       anvar@gmail.com
# olim        olimtoy      olimtoy@gmail.ru
# maryam   mary334455      mary33@gmail.com
# javohir   javohir45  javohir445@gmail.com

# %%
df.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')

# %%
data2 = {
    'username':{"olim":"olimjon21", "maryam":"maryam2020"},
    'email':{"olim":"olimjon21@gmail.com","maryam":"maryam20@gmail.com"}
}

# %%
df3 = df.append(pd.DataFrame(data2))
df3
# Out:
# <ipython-input-33-4434c8f09b14>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df.append(pd.DataFrame(data2))
#            username                 email
# anvar    anvarbek23       anvar@gmail.com
# olim        olimtoy      olimtoy@gmail.ru
# maryam   mary334455      mary33@gmail.com
# javohir   javohir45  javohir445@gmail.com
# olim      olimjon21   olimjon21@gmail.com
# maryam   maryam2020    maryam20@gmail.com

# %%
newind = pd.Index(['olim','nafisa','hamida'])
newind
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
newind.isin(df2.index)
# Out:
# array([False, False, False])

# %%
df3.index.union(newind)
# Out:
# Index(['anvar', 'hamida', 'javohir', 'maryam', 'maryam', 'nafisa', 'olim',
#        'olim'],
#       dtype='object')

# %%
df3.index.delete(0)
# Out:
# Index(['olim', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
newind
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
newind.drop('hamida')
# Out:
# Index(['olim', 'nafisa'], dtype='object')

# %%
##################################################################################################################################################

# %%
data4 = {'Yil':[2021,2020,2019,2018,2017,2016,2015,2010],
         'Aholi soni':[33.9,33.5,32.9,32.5,31.9,31.4,30.9,28.5],
         'Temp':[1.54,1.48,1.56,1.62,1.65,1.66,1.64,1.53],
         'Zichlik':[79.77,78.68,77.53,76.34,75.13,73.91,72.71,67.03]}
df6 = pd.DataFrame(data4)
df6
# Out:
#     Yil  Aholi soni  Temp  Zichlik
# 0  2021        33.9  1.54    79.77
# 1  2020        33.5  1.48    78.68
# 2  2019        32.9  1.56    77.53
# 3  2018        32.5  1.62    76.34
# 4  2017        31.9  1.65    75.13
# 5  2016        31.4  1.66    73.91
# 6  2015        30.9  1.64    72.71
# 7  2010        28.5  1.53    67.03

# %%
ind = [21,20,19,18,17,16,15,10]
ind.sort()
ind
# Out:
# [10, 15, 16, 17, 18, 19, 20, 21]

# %%
df6=df6.reindex(ind)

# %%
df6
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df6.reindex(index=range(10,22), method='ffill')
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 11  2010        28.5  1.53    67.03
# 12  2010        28.5  1.53    67.03
# 13  2010        28.5  1.53    67.03
# 14  2010        28.5  1.53    67.03
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df6.reindex(columns=['Aholi soni', 'Temp','Zichlik'])
df6.sample(3)
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 16  2016        31.4  1.66    73.91
# 15  2015        30.9  1.64    72.71
# 18  2018        32.5  1.62    76.34

# %%
df6.loc[[10,15,18,20],['Aholi soni','Temp','Zichlik']]
# Out:
#     Aholi soni  Temp  Zichlik
# 10        28.5  1.53    67.03
# 15        30.9  1.64    72.71
# 18        32.5  1.62    76.34
# 20        33.5  1.48    78.68
