# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulxoliqMirzayev/PandasLibrary/blob/main/DataFrame_malumotlar_tuzilmasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Yil':[2021,2020,2019,2018,2017,2016,2015,2010],
    'Aholi soni':[33.9,33.5,32.9,32.5,31.9,31.4,30.9,28.5],
    'Temp':[1.54,1.48,1.56,1.62,1.65,1.66,1.64,1.53]
}
df=pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
df.head()
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65

# %%
df.shape
# Out:
# (8, 3)

# %%
#### Data frame ustunlari

# %%
df = pd.DataFrame(data, columns = ['Yil','Temp','Aholi soni'])

# %%
df
# Out:
#     Yil  Temp  Aholi soni
# 0  2021  1.54        33.9
# 1  2020  1.48        33.5
# 2  2019  1.56        32.9
# 3  2018  1.62        32.5
# 4  2017  1.65        31.9
# 5  2016  1.66        31.4
# 6  2015  1.64        30.9
# 7  2010  1.53        28.5

# %%
df = pd.DataFrame(data, columns = ['Yil','Temp','Aholi soni', 'YAIM'])

# %%
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# 0  2021  1.54        33.9  NaN
# 1  2020  1.48        33.5  NaN
# 2  2019  1.56        32.9  NaN
# 3  2018  1.62        32.5  NaN
# 4  2017  1.65        31.9  NaN
# 5  2016  1.66        31.4  NaN
# 6  2015  1.64        30.9  NaN
# 7  2010  1.53        28.5  NaN

# %%
df['Aholi soni']
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# 4    31.9
# 5    31.4
# 6    30.9
# 7    28.5
# Name: Aholi soni, dtype: float64

# %%
df.Temp
# Out:
# 0    1.54
# 1    1.48
# 2    1.56
# 3    1.62
# 4    1.65
# 5    1.66
# 6    1.64
# 7    1.53
# Name: Temp, dtype: float64

# %%
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# 0  2021  1.54        33.9  NaN
# 1  2020  1.48        33.5  NaN
# 2  2019  1.56        32.9  NaN
# 3  2018  1.62        32.5  NaN
# 4  2017  1.65        31.9  NaN
# 5  2016  1.66        31.4  NaN
# 6  2015  1.64        30.9  NaN
# 7  2010  1.53        28.5  NaN

# %%
df.YAIM=0
df
# Out:
#     Yil  Temp  Aholi soni  YAIM
# 0  2021  1.54        33.9     0
# 1  2020  1.48        33.5     0
# 2  2019  1.56        32.9     0
# 3  2018  1.62        32.5     0
# 4  2017  1.65        31.9     0
# 5  2016  1.66        31.4     0
# 6  2015  1.64        30.9     0
# 7  2010  1.53        28.5     0

# %%
val = pd.Series([1700,1650,1750,1350,1480,1700,1800])
df.YAIM=val
df
# Out:
#     Yil  Temp  Aholi soni    YAIM
# 0  2021  1.54        33.9  1700.0
# 1  2020  1.48        33.5  1650.0
# 2  2019  1.56        32.9  1750.0
# 3  2018  1.62        32.5  1350.0
# 4  2017  1.65        31.9  1480.0
# 5  2016  1.66        31.4  1700.0
# 6  2015  1.64        30.9  1800.0
# 7  2010  1.53        28.5     NaN

# %%
df['1500+']= df.YAIM>1500
df
# Out:
#     Yil  Temp  Aholi soni    YAIM  1500+
# 0  2021  1.54        33.9  1700.0   True
# 1  2020  1.48        33.5  1650.0   True
# 2  2019  1.56        32.9  1750.0   True
# 3  2018  1.62        32.5  1350.0  False
# 4  2017  1.65        31.9  1480.0  False
# 5  2016  1.66        31.4  1700.0   True
# 6  2015  1.64        30.9  1800.0   True
# 7  2010  1.53        28.5     NaN  False

# %%
del df['1500+']
df
# Out:
#     Yil  Temp  Aholi soni    YAIM
# 0  2021  1.54        33.9  1700.0
# 1  2020  1.48        33.5  1650.0
# 2  2019  1.56        32.9  1750.0
# 3  2018  1.62        32.5  1350.0
# 4  2017  1.65        31.9  1480.0
# 5  2016  1.66        31.4  1700.0
# 6  2015  1.64        30.9  1800.0
# 7  2010  1.53        28.5     NaN

# %%
#### Lug'atdan dta frame******************************

# %%
data1 = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}

# %%
df2 = pd.DataFrame(data1)
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2.index.name='Yil'
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2=pd.DataFrame(data1,index=[2021,2019,2017])
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
df2.T
# Out:
#             2021  2019  2017
# Uzbekistan  33.9  32.9  31.9
# Kazakhstan  18.9  18.5  18.1

# %%
arr =df2.values
arr
# Out:
# array([[33.9, 18.9],
#        [32.9, 18.5],
#        [31.9, 18.1]])

# %%
type(arr)
# Out:
# numpy.ndarray
